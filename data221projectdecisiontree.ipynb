# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

df = pd.read_csv("Data221projectDecisionTree/train.csv")
df.head()

# seperating input and target variable
X = df.drop("price_range", axis=1)
y = df["price_range"]

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25, random_state=42, stratify=y)
# decision tree
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)

y_prediction = model.predict(X_test)
accuracy = accuracy_score(y_test, y_prediction)
accuracy_percentage = round(accuracy * 100,2)
print("Model Accuracy is:", accuracy_percentage, "%")

print(classification_report(y_test, y_prediction))

print(confusion_matrix(y_test, y_prediction))

# features importance
feature_importance_df = pd.DataFrame({"Feature": X.columns,"Importance": model.feature_importances_}).sort_values(by="Importance", ascending=False)

print(feature_importance_df)
# Out:
# Model Accuracy is: 82.4 %
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88       125
#            1       0.80      0.74      0.77       125
#            2       0.76      0.79      0.77       125
#            3       0.88      0.86      0.87       125
#
#     accuracy                           0.82       500
#    macro avg       0.82      0.82      0.82       500
# weighted avg       0.82      0.82      0.82       500
#
# [[113  12   0   0]
#  [ 18  93  14   0]
#  [  0  11  99  15]
#  [  0   0  18 107]]
#           Feature  Importance
# 13            ram    0.650723
# 12       px_width    0.090529
# 11      px_height    0.085406
# 0   battery_power    0.081669
# 8       mobile_wt    0.016283
# 7           m_dep    0.013647
# 6      int_memory    0.010889
# 2     clock_speed    0.010161
# 4              fc    0.005479
# 15           sc_w    0.005457
# 1            blue    0.005418
# 16      talk_time    0.005053
# 14           sc_h    0.005051
# 10             pc    0.004730
# 9         n_cores    0.003727
# 3        dual_sim    0.003556
# 18   touch_screen    0.002222
# 5          four_g    0.000000
# 17        three_g    0.000000
# 19           wifi    0.000000
